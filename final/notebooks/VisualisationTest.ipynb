# %%
import json
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '/home/tim/Documents/Modeling-and-Data-Analysis-in-Complex-Networks/final/')

import GraphLoader

print("Imports loaded")
# Out:
# Imports loaded

# %%
traffic_graph = GraphLoader.load_traffic_graph()
subgraph = GraphLoader.load_page_subgraph()

# %%
# Visualise traffic pages

# fig, ax = plt.subplots(1, 1, figsize=(30, 30));
# nx.draw(traffic_graph, ax=ax)

# plt.savefig('figures/testsvg.svg', format='svg')
# print("done")

# %%
# Visualise all pages
# Takes EXTREMELY long

# G = GraphLoader.load_page_graph()

# fig, ax = plt.subplots(1, 1, figsize=(400, 400));
# nx.draw(G, ax=ax)
# plt.savefig('figures/all_pages_svg.svg', format='svg')
# print("done")

# %%
# fig, ax = plt.subplots(1, 1, figsize=(50, 50));
# nx.draw(subgraph, ax=ax)
# # plt.show()


# plt.savefig('../figures/subgraph3.svg', format='svg')
# print("done")
# Out:
# /home/tim/Downloads/Enter/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# /home/tim/Downloads/Enter/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-d54fceae30e6> in <module>
#       4
#       5
# ----> 6 plt.savefig('../figures/subgraph3.svg', format='svg')
#       7 print("done")
#
# ~/Downloads/Enter/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     720 def savefig(*args, **kwargs):
# ...

# %%
# nx.number_connected_components(subgraph.to_undirected())

# %%
# [p for p,d in subgraph.degree() if abs(d) < 1]

# %%
# sp = dict(nx.all_pairs_shortest_path(subgraph))

# %%
G = subgraph.to_undirected()
components = nx.connected_component_subgraphs(G)
bla = {}
[[bla.update({k:v}) for k,v in nx.betweenness_centrality(c).items()] for c in components][0]

[d['attr_data'].update({'betweenness': bla[n]}) for n, d in subgraph.nodes(data=True)]

subgraph.nodes(data=True)
# Out:
# NodeDataView({'https://www.tudelft.nl/bk/studeren/minoren-en-keuzevakken/cities-migration-socio-spatial-inequality/': {'attr_data': {'id': 363569290, 'title': 'Cities, Migration & Socio-Spatial Inequality', 'url': 'https://www.tudelft.nl/bk/studeren/minoren-en-keuzevakken/cities-migration-socio-spatial-inequality/', 'average_page_views_per_visit': 1.68, 'bounce_rate': 50.0, 'has_integration': False, 'page_views': 32, 'visits': 19, 'betweenness': 0.002165838083660577}}, 'https://www.tudelft.nl/library/collecties/normen-statistieken-en-meer/': {'attr_data': {'id': 664034069, 'title': 'Normen, statistieken en meer', 'url': 'https://www.tudelft.nl/library/collecties/normen-statistieken-en-meer/', 'average_page_views_per_visit': 1.0, 'bounce_rate': 50.0, 'has_integration': False, 'page_views': 13, 'visits': 13, 'betweenness': 0.005479431405357331}}, 'https://www.tudelft.nl/en/architecture-and-the-built-environment/research/projects/urbanism/': {'attr_data': {'id': 363676779, 'title': 'Urb
# ...
